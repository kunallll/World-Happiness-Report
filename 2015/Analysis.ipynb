# %% [markdown]
# # World Happiness Report (2015)
#
# **Happiness:** The term happiness is used in the context of mental or emotional states, including positive or pleasant emotions ranging from contentment to intense joy. It is also used in the context of life satisfaction, subjective well-being, eudaimonia, flourishing and well-being.
#
# **The World Happiness Report** is an annual publication of the United Nations Sustainable Development Solutions Network. It contains articles, and rankings of national happiness based on respondent ratings of their own lives, which the report also correlates with various life factors. As of March 2020, Finland was ranked the happiest country in the world three times in a row.
#
# The Editors of the report are John F. Helliwell, Richard Layard, Jeffrey D. Sachs, and Jan-Emmanuel De Neve. Associate Editors are Lara B. Aknin, Shun Wang, and Haifang Huang.
#
# Below is the analysis that would explain the various factors involved in calculating the happiness of a particular country's citizens.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Attributes:
# 1. Country
# 2. Region
# 3. Happiness Rank
# 4. Happiness Score
# 5. Standard Error
# 6. Economy
# 7. Family
# 8. Health(Life Expectancy)
# 9. Freedom
# 10. Trust
# 11. Generosity
# 12. Dystopia

# %%
df_2015 = pd.read_csv('2015.csv')

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ## Correlation between attributes

# %%
sns.pairplot(df_2015.drop(['Standard Error', 'Dystopia Residual'], axis=1))

# %%
df_2015.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [markdown]
# ### The correlation that needs to be looked importantly is between the happiness score and all the other attributes:
# 1. Happiness score - Economy (0.780966)
# 2. Happiness score - Family (0.740605)
# 3. Happiness score - Health (0.724200)
# 4. Happiness score - Freedom (0.568211)
# 5. Happiness score - Trust (0.395199)
# 6. Happiness score - Generosity (0.180319)

# %% [markdown]
# ## Happiness score:

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15,8))
sns.distplot(df_2015['Happiness Score'], kde=False)

# %% [markdown]
# Most countries have been rated an average of 5-6 points and the highest any country has achieved is a score of 7.53 (Switzerland). The happiness score depends on various factors. The plot before this explained the same.

# %% [markdown]
# ## Top 5 Countries (2015)
#
# Below are the top 5 countries and their plots on the basis of the attributes:
# 1. Economy (GDP per Capita)
# 2. Family
# 3. Health (Life Expectancy)
# 4. Freedom
# 5. Trust (Government Corruption)
# 6. Generosity
#
# This is also the order in which the affect the happiness score of a particular country.

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ### Top 5 countries and their attribute values

# %%
sns.set_style('darkgrid')
fig, axs = plt.subplots(1, 6, figsize=(25, 8))

axs[0].tick_params(labelrotation=90)
axs[1].tick_params(labelrotation=90)
axs[2].tick_params(labelrotation=90)
axs[3].tick_params(labelrotation=90)
axs[4].tick_params(labelrotation=90)
axs[5].tick_params(labelrotation=90)

axs[0].title.set_text('Economy')
axs[1].title.set_text('Health')
axs[2].title.set_text('Family')
axs[3].title.set_text('Freedom')
axs[4].title.set_text('Trust')
axs[5].title.set_text('Generosity')

sns.lineplot(df_2015.head()['Country'], df_2015.head()['Economy (GDP per Capita)'], ax=axs[0])
sns.lineplot(df_2015.head()['Country'], df_2015.head()['Health (Life Expectancy)'], ax=axs[1])
sns.lineplot(df_2015.head()['Country'], df_2015.head()['Family'], ax=axs[2])
sns.lineplot(df_2015.head()['Country'], df_2015.head()['Freedom'], ax=axs[3])
sns.lineplot(df_2015.head()['Country'], df_2015.head()['Trust (Government Corruption)'], ax=axs[4])
sns.lineplot(df_2015.head()['Country'], df_2015.head()['Generosity'], ax=axs[5])

# %%
plt.figure(figsize=(15,8))

plt.title('Happiness Score Of Top 5')

sns.lineplot(df_2015.head()['Country'], df_2015.head()['Happiness Score'])
sns.scatterplot(df_2015.head()['Country'], df_2015.head()['Happiness Score'])

# %% [markdown]
# ### Top 5 countries are:
#
# 1. Switzerland
# 2. Iceland
# 3. Denmark
# 4. Norway
# 5. Canada
#
# Switzerland had a score of 7.587. Multiple factors played an important role in making switzerland the happiest place. As seen in the above graphs and plots, switzedland has had very good health care, economy and is also very democratic. (Refer: https://www.telegraph.co.uk/travel/destinations/europe/switzerland/articles/Why-is-Switzerland-so-happy/)

# %% [markdown]
# ## Bottom 5 Countries (2015)
#
# Below are the bottom 5 countries and their plots on the basis of the attributes:
# 1. Economy (GDP per Capita)
# 2. Family
# 3. Health (Life Expectancy)
# 4. Freedom
# 5. Trust (Government Corruption)
# 6. Generosity
#
# This is also the order in which the affect the happiness score of a particular country.

# %%
df_2015.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %% [markdown]
# ### Bottom 5 countries and their attribute scores

# %%
sns.set_style('darkgrid')
fig, axs = plt.subplots(1, 6, figsize=(25, 8))

axs[0].tick_params(labelrotation=90)
axs[1].tick_params(labelrotation=90)
axs[2].tick_params(labelrotation=90)
axs[3].tick_params(labelrotation=90)
axs[4].tick_params(labelrotation=90)
axs[5].tick_params(labelrotation=90)

axs[0].title.set_text('Economy')
axs[1].title.set_text('Health')
axs[2].title.set_text('Family')
axs[3].title.set_text('Freedom')
axs[4].title.set_text('Trust')
axs[5].title.set_text('Generosity')

sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Economy (GDP per Capita)'], ax=axs[0])
sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Health (Life Expectancy)'], ax=axs[1])
sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Family'], ax=axs[2])
sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Freedom'], ax=axs[3])
sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Trust (Government Corruption)'], ax=axs[4])
sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Generosity'], ax=axs[5])

# %%
plt.figure(figsize=(15,8))

plt.title('Happiness Score Of Top 5')

sns.lineplot(df_2015.tail()['Country'], df_2015.tail()['Happiness Score'])
sns.scatterplot(df_2015.tail()['Country'], df_2015.tail()['Happiness Score'])

# %% [markdown]
# ### Bottom 5 countries are:
#
# 1. Togo
# 2. Burundi
# 3. Syria
# 4. Benin
# 5. Rwanda
#
# Most of the six dimensions used to measure happiness are tied in one way or another to poverty, which is omnipresent in Togo. Not only are Togo’s GDP and life expectancy among the lowest in the world, other measures including social support and generosity are severely limited by a lack of resources.(Refer: https://www.huffpost.com/entry/what-we-can-learn-from-wo_b_8015922)

# %% [markdown]
# ## Region wise distribution of Happiness
#
# The entire world is divided into 10 **regions**, these are:
# 1. Western Europe
# 2. North America
# 3. Australia and New Zealand
# 4. Middle East and Northern Africa
# 5. Latin America and Caribbean
# 6. Southeastern Asia
# 7. Central and Eastern Europe
# 8. Eastern Asia
# 9. Sub-Saharan Africa
# 10. Southern Asia
#
# Below is the distribution of countries according to their regions.

# %%
HS = df_2015.groupby('Region')['Happiness Score'].mean()
Ec = df_2015.groupby('Region')['Economy (GDP per Capita)'].mean()
He = df_2015.groupby('Region')['Health (Life Expectancy)'].mean()
Fa = df_2015.groupby('Region')['Family'].mean()
Ge = df_2015.groupby('Region')['Generosity'].mean()
Tr = df_2015.groupby('Region')['Trust (Government Corruption)'].mean()
Fe = df_2015.groupby('Region')['Freedom'].mean()

# %%
fig, axs = plt.subplots(1, 2, figsize=(25, 8))

axs[0].title.set_text('Attributes')
axs[1].title.set_text('Happiness Score')

axs[0].tick_params(labelrotation=90)
axs[1].tick_params(labelrotation=90)

sns.lineplot(Ec.index, list(Ec), label='Economy', ax=axs[0])
sns.lineplot(He.index, list(He), label='Health', ax=axs[0])
sns.lineplot(Fa.index, list(Fa), label='Family', ax=axs[0])
sns.lineplot(Ge.index, list(Ge), label='Generosity', ax=axs[0])
sns.lineplot(Tr.index, list(Tr), label='Trust', ax=axs[0])
sns.lineplot(Fe.index, list(Fe), label='Freedom', ax=axs[0])
plt.legend()

sns.barplot(HS.index, list(HS), ax=axs[1], palette='YlGnBu')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Percentage country distribution, Region wise.

# %%
slices = df_2015.Region.value_counts()/158

plt.figure(figsize = (10, 8))
plt.pie(slices, labels=list(slices.index), autopct='%.2f')

print('Count of countries, Region wise:')
print()
print(df_2015['Region'].value_counts())
plt.show()
# Out:
# Count of countries, Region wise:
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# ## Result:
#
# The **World Happiness Report** (WHR, https://worldhappiness.report/), it is report that ranks countries on the basis of happiness, and this happiness is measured using various factors (income, poverty, education, health and good government). The World happiness report was first published in the year 2012. It was inspired **Gross domestic Happiness** adopted by the constitution of Bhutan in the year 2008. The report primarily uses data from the Gallup World Poll. Each annual report is available to the public to download on the World Happiness Report website.
#
# #### Methodology:
#
# The rankings of national happiness are based on a Cantril ladder survey. Nationally representative samples of respondents are asked to think of a ladder, with the best possible life for them being a 10, and the worst possible life being a 0. They are then asked to rate their own current lives on that 0 to 10 scale. The report correlates the results with various life factors.
#
# In the reports, experts in fields including economics, psychology, survey analysis, and national statistics, describe how measurements of well-being can be used effectively to assess the progress of nations, and other topics. Each report is organized by chapters that delve deeper into issues relating to happiness, including mental illness, the objective benefits of happiness, the importance of ethics, policy implications, and links with the Organisation for Economic Co-operation and Development's (OECD) approach to measuring subjective well-being and other international and national efforts.
#
# Most Nordic countries topped the list, the reasons are simple and clear, they have good economic, health, government infrastructures.
#
#     "The feeling in US is that you need to be protected by the Govt, here it is the Govt that protects you."-Miek Wiking, CEO, Happiness institute Denmark. (Refer: https://www.youtube.com/watch?v=6Pm0Mn0-jYU)
# The Health infrasturture is so good. Education is free till 12th grade. Most of the countries have all of these in similar. If you're jobless, the Govt provides you with money. (Refer: https://www.youtube.com/watch?v=6Pm0Mn0-jYU)
#
# Paid parental leaves, lower health care costs, educations, transparency. But also do these countries have higher taxes. But looking at many of the positives, people are willing to pay higer taxes.
#
#
# #### Criticism:
#
# Many have argued that happiness can't be measured this way, it's considered to be unique for every person.
#
#     "the Dalai Lama, Gandhi, Tolstoy and several others, happiness is an individual choice that is independent of the society, its structures and enabling or dis-enabling conditions and not something to be measured using variables that can only capture a nation's well-being. This means therefore that one cannot really talk of a happy or unhappy nation, but of happy or unhappy individuals." (https://en.wikipedia.org/wiki/World_Happiness_Report).
#
# Togo is considered to be least ranked in this list, while looking through various articles this one article spoke about togo in specific(https://www.huffpost.com/entry/what-we-can-learn-from-wo_b_8015922),
#
#     "In spite of the devastating poverty and lack of basic infrastructure that exists in Togo, the women of Togo have seemingly figured out what many Americans turn to expensive therapy, counseling, and yoga retreats to seek out: namely positivity, generosity of spirit, and hope that their children’s lives will be better than their own."
#
# Similarly Rwanda, it is small country present in Sub-Saharan Africa. The 2013 Rwandan Parliamentary elections ushered in a record-breaking 64 per cent of seats for women candidates, making Rwanda the top country for women in politics.
